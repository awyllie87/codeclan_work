# %%
import pandas as pd

# %%
demographic_data = pd.read_csv("data/life_expectancy_and_income_missing.csv")

# %%
demographic_data.describe()
# Out:
#                year  fertility_rate  income_per_person  life_expectancy
# count  22080.000000    22080.000000       22066.000000     21896.000000
# mean    1959.500000        4.840770        7608.560274        52.725449
# std       34.640598        1.916428       13450.013474        16.743644
# min     1900.000000        1.120000         312.000000         1.100000
# 25%     1929.750000        2.980000        1370.000000        35.800000
# 50%     1959.500000        5.450000        2880.000000        53.800000
# 75%     1989.250000        6.500000        7710.000000        68.300000
# max     2019.000000        8.870000      179000.000000        85.100000

# %% [markdown]
# ## summarised details of data frame

# %%
demographic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22080 entries, 0 to 22079
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            22080 non-null  object
#  1   year               22080 non-null  int64
#  2   fertility_rate     22080 non-null  float64
#  3   income_per_person  22066 non-null  float64
#  4   life_expectancy    21896 non-null  float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 862.6+ KB

# %% [markdown]
# For the exercises in this lesson we'll use a dataset about occupational prestige. Here is some information on the variables contained in the data.
# education Average years of education of occupational incumbents, years, in 1971.
# - income Average income of incumbents, dollars, in 1971.
# - women Percentage of incumbents who are women.
# - prestige Pineo-Porter prestige score for occupation, from a social survey conducted in the mid-1960s.
# - census Canadian Census occupational code.
# - type Type of occupation. A factor with levels (note: out of order): bc, Blue Collar; prof, Professional, Managerial, and Technical; wc, White Collar.
#
# Read in the file prestige_occupation.csv. Save it as an object called occupation_prestige.
# - How many rows and columns are in the data?
# - What is the average (mean) value for the column prestige (hint: you can use describe to answer this).

# %%
prestige_occupation = pd.read_csv("data/prestige_occupation.csv")

# %%
prestige_occupation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   job        102 non-null    object
#  1   education  102 non-null    float64
#  2   income     102 non-null    int64
#  3   women      97 non-null     float64
#  4   prestige   102 non-null    float64
#  5   census     102 non-null    int64
#  6   type       98 non-null     object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 5.7+ KB

# %%
prestige_occupation.describe()
# Out:
#         education        income      women    prestige       census
# count  102.000000    102.000000  97.000000  102.000000   102.000000
# mean    10.738039   6797.901961  30.472784   46.833333  5401.774510
# std      2.728444   4245.922227  31.826063   17.204486  2644.993215
# min      6.380000    611.000000   0.520000   14.800000  1113.000000
# 25%      8.445000   4106.000000   4.140000   35.225000  3120.500000
# 50%     10.540000   5930.500000  15.510000   43.600000  5135.000000
# 75%     12.647500   8187.250000  54.770000   59.275000  8312.500000
# max     15.970000  25879.000000  97.510000   87.200000  9517.000000

# %% [markdown]
# 102 rows, 6 columns
#
# mean prestige = 46.83

# %%
demographic_data_copy = demographic_data.copy

# %%
demographic_data[(demographic_data["country"] == "Japan") & (demographic_data["year"] > 2000)]
# Out:
#      country  year  fertility_rate  income_per_person  life_expectancy
# 9821   Japan  2001            1.31            33900.0             81.7
# 9822   Japan  2002            1.30            33900.0             82.0
# 9823   Japan  2003            1.30            34300.0             82.1
# 9824   Japan  2004            1.30            35100.0             82.3
# 9825   Japan  2005            1.31            35700.0             82.3
# 9826   Japan  2006            1.32            36100.0             82.6
# 9827   Japan  2007            1.33            36700.0             82.8
# 9828   Japan  2008            1.34            36300.0             82.9
# 9829   Japan  2009            1.36            34300.0             83.1
# 9830   Japan  2010            1.37            35800.0             83.1
# 9831   Japan  2011            1.39            35800.0             82.9
# 9832   Japan  2012            1.40            36400.0             83.4
# ...

# %%
demographic_data[(demographic_data["country"] == "Japan") | (demographic_data["country"] == "Sweden")]
# Out:
#       country  year  fertility_rate  income_per_person  life_expectancy
# 9720    Japan  1900            4.69             1860.0             38.7
# 9721    Japan  1901            5.01             1900.0              NaN
# 9722    Japan  1902            4.97             1780.0             39.0
# 9723    Japan  1903            4.83             1880.0             39.1
# 9724    Japan  1904            4.61             1870.0             39.2
# ...       ...   ...             ...                ...              ...
# 19075  Sweden  2015            1.91            45700.0             82.2
# 19076  Sweden  2016            1.91            46300.0             82.4
# 19077  Sweden  2017            1.91            46700.0             82.5
# 19078  Sweden  2018            1.91            47200.0             82.6
# 19079  Sweden  2019            1.91            47200.0             82.8
#
# [240 rows x 5 columns]

# %%
demographic_data[demographic_data["country"]].isin("Japan")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 demographic_data[demographic_data["country"]].isin("Japan")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
# ...

# %% [markdown]
# ## maximum and minimum entries

# %%
demographic_data.loc[demographic_data["life_expectancy"].idxmax()]
# Out:
# country              Singapore
# year                      2019
# fertility_rate            1.27
# income_per_person      90100.0
# life_expectancy           85.1
# Name: 17279, dtype: object

# %%
demographic_data.loc[demographic_data["life_expectancy"].idxmin()]
# Out:
# country               Samoa
# year                   1918
# fertility_rate         6.98
# income_per_person    2050.0
# life_expectancy         1.1
# Name: 16338, dtype: object

# %%
samoa_data = demographic_data[demographic_data["country"] == "Samoa"]

samoa_data["life_expectancy"].unique()
# Out:
# array([27.1,  nan, 27.2, 27.3, 27.4, 27.5, 27.6, 27.7, 27.8, 27.9, 28. ,
#         1.1, 28.1, 28.2, 28.3, 28.4, 28.5, 28.6, 28.7, 28.8, 28.9, 30.4,
#        31.8, 33.3, 34.7, 36.2, 37.7, 39.1, 40.6, 42.1, 43.6, 45.1, 46.6,
#        48.1, 49.6, 51.1, 52.7, 53.1, 53.8, 54.5, 55.2, 55.9, 56.6, 57.4,
#        58.1, 58.8, 59.5, 60.2, 60.9, 61.6, 62.3, 63. , 63.8, 64.5, 65.2,
#        65.9, 66.7, 67.2, 67.7, 68.1, 68.6, 68.8, 69.2, 69.3, 69.4, 69.6,
#        69.7, 69.9, 70.1, 70.3, 70.4, 70.6, 70.8, 70.7, 71. , 71.1, 71.3,
#        71.5, 71.6, 71.7, 71.8, 72. , 72.1, 72.2, 72.4, 72.5, 72.3, 72.6,
#        72.7, 72.8, 72.9, 73. , 73.2])

# %% [markdown]
# ## sort data

# %%
demographic_data.sort_values("life_expectancy", ascending=False, inplace = True)

demographic_data
# Out:
#          country  year  fertility_rate  income_per_person  life_expectancy
# 17279  Singapore  2019            1.27            90100.0             85.1
# 17278  Singapore  2018            1.26            90100.0             85.0
# 17277  Singapore  2017            1.25            87800.0             84.8
# 17276  Singapore  2016            1.25            84700.0             84.7
# 9839       Japan  2019            1.50            39700.0             84.5
# ...          ...   ...             ...                ...              ...
# 21481  Venezuela  1901            5.64             2000.0              NaN
# 21601    Vietnam  1901            4.66              969.0              NaN
# 21721      Yemen  1901            6.88             1170.0              NaN
# 21841     Zambia  1901            6.71              847.0              NaN
# 21961   Zimbabwe  1901            6.75              981.0              NaN
#
# [22080 rows x 5 columns]

# %% [markdown]
# ## Renaming Columns

# %%
demographic_data.rename(columns = {"income_per_person":"income_gdp_perhead_ppp_in_dollars"})
# Out:
#          country  year  fertility_rate  income_gdp_perhead_ppp_in_dollars  \
# 17279  Singapore  2019            1.27                            90100.0
# 17278  Singapore  2018            1.26                            90100.0
# 17277  Singapore  2017            1.25                            87800.0
# 17276  Singapore  2016            1.25                            84700.0
# 9839       Japan  2019            1.50                            39700.0
# ...          ...   ...             ...                                ...
# 21481  Venezuela  1901            5.64                             2000.0
# 21601    Vietnam  1901            4.66                              969.0
# 21721      Yemen  1901            6.88                             1170.0
# 21841     Zambia  1901            6.71                              847.0
# 21961   Zimbabwe  1901            6.75                              981.0
#
#        life_expectancy
# 17279             85.1
# 17278             85.0
# ...

# %% [markdown]
# In the occupation_prestige data frame, change the name of the column job to job_title. (Hint: think about how we make changes persist). Check the occupation_prestige dataframe to see if it worked.

# %%
prestige_occupation.rename(columns = {"job":"job_title"}, inplace = True)

prestige_occupation
# Out:
#                job_title  education  income  women  prestige  census  type
# 0     gov.administrators      13.11   12351  11.16      68.8    1113  prof
# 1       general.managers      12.26   25879   4.02      69.1    1130  prof
# 2            accountants      12.77    9271  15.70      63.4    1171  prof
# 3    purchasing.officers      11.42    8865   9.11      56.8    1175  prof
# 4               chemists      14.62    8403  11.68      73.5    2111  prof
# ..                   ...        ...     ...    ...       ...     ...   ...
# 97           bus.drivers       7.58    5562   9.47      35.9    9171    bc
# 98          taxi.drivers       7.93    4224   3.59      25.1    9173    bc
# 99          longshoremen       8.37    4753    NaN      26.1    9313    bc
# 100          typesetters      10.00    6462  13.58      42.2    9511    bc
# 101          bookbinders       8.55    3617  70.87      35.2    9517    bc
#
# [102 rows x 7 columns]

# %%
demographic_data["years_since_1990"] = demographic_data["year"] - 1990

demographic_data
# Out:
#          country  year  fertility_rate  income_per_person  life_expectancy  \
# 17279  Singapore  2019            1.27            90100.0             85.1
# 17278  Singapore  2018            1.26            90100.0             85.0
# 17277  Singapore  2017            1.25            87800.0             84.8
# 17276  Singapore  2016            1.25            84700.0             84.7
# 9839       Japan  2019            1.50            39700.0             84.5
# ...          ...   ...             ...                ...              ...
# 21481  Venezuela  1901            5.64             2000.0              NaN
# 21601    Vietnam  1901            4.66              969.0              NaN
# 21721      Yemen  1901            6.88             1170.0              NaN
# 21841     Zambia  1901            6.71              847.0              NaN
# 21961   Zimbabwe  1901            6.75              981.0              NaN
#
#        years_since_1990
# 17279                29
# ...

# %%
demographic_data.isnull().sum()
# Out:
# country                0
# year                   0
# fertility_rate         0
# income_per_person     14
# life_expectancy      184
# years_since_1990       0
# dtype: int64

# %%
demographic_data.fillna(0, inplace=True)

demographic_data.isnull().sum()
# Out:
# country              0
# year                 0
# fertility_rate       0
# income_per_person    0
# life_expectancy      0
# years_since_1990     0
# dtype: int64

# %% [markdown]
# ## Visualisations
#
# - be able to use numpy arrays to create some plots
# - be able to create some basic plots from pandas df

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
plt.plot([0,1,4,9,16,20])

# %%
x = np.linspace(0, 10, 20)

y1 = x**2

y2 = x**1.5

# %%
plt.plot(x,y1)

# %%
plt.plot(x,y1,"ro-")

# %% [markdown]
# ### histograms

# %%
x = np.random.normal(size=1000)
plt.hist(x)
# Out:
# (array([  1.,  10.,  27.,  89., 166., 281., 236., 141.,  38.,  11.]),
#  array([-3.98119395, -3.27300724, -2.56482053, -1.85663382, -1.1484471 ,
#         -0.44026039,  0.26792632,  0.97611303,  1.68429974,  2.39248645,
#          3.10067317]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Built in plotting

# %%
demo_data_2019 = demographic_data[demographic_data["year"] == 2019].copy()

demo_data_2019
# Out:
#                         country  year  fertility_rate  income_per_person  \
# 17279                 Singapore  2019            1.27            90100.0
# 9839                      Japan  2019            1.50            39700.0
# 19199               Switzerland  2019            1.56            59000.0
# 9599                      Italy  2019            1.51            35800.0
# 9479                     Israel  2019            2.89            34100.0
# ...                         ...   ...             ...                ...
# 18119               South Sudan  2019            4.62             1860.0
# 17759                   Somalia  2019            5.98              631.0
# 15239          Papua New Guinea  2019            3.52             3930.0
# 11039                   Lesotho  2019            2.95             2920.0
# 3839   Central African Republic  2019            4.65              794.0
#
#        life_expectancy  years_since_1990
# 17279             85.1                29
# ...

# %%
plt.rcParams["figure.figsize"] = [5,3]
plt.rcParams["figure.dpi"] = 120
plt.rcParams["font.size"] = 12

# %% [markdown]
# ### Scatter Plot

# %%
plt.scatter(x='income_per_person',
            y= "life_expectancy",
            data = demo_data_2019)

# %% [markdown]
# ### Adding labels
#
# - plt.xlabel
# - plt.ylabel
# - plt.title

# %%
plt.scatter(x='income_per_person',
            y= "life_expectancy",
            data = demo_data_2019)
plt.xlabel("Income per per person ($,ppp)")
plt.ylabel("Life expactancy")
plt.title("Scatterplot of income per person vs life expectancy")
# Out:
# Text(0.5, 1.0, 'Scatterplot of income per person vs life expectancy')

# %%
demo_data_2019.loc[:, "income_per_person_1000"] = demo_data_2019["income_per_person"] / 1000
demo_data_2019
# Out:
#                         country  year  fertility_rate  income_per_person  \
# 17279                 Singapore  2019            1.27            90100.0
# 9839                      Japan  2019            1.50            39700.0
# 19199               Switzerland  2019            1.56            59000.0
# 9599                      Italy  2019            1.51            35800.0
# 9479                     Israel  2019            2.89            34100.0
# ...                         ...   ...             ...                ...
# 18119               South Sudan  2019            4.62             1860.0
# 17759                   Somalia  2019            5.98              631.0
# 15239          Papua New Guinea  2019            3.52             3930.0
# 11039                   Lesotho  2019            2.95             2920.0
# 3839   Central African Republic  2019            4.65              794.0
#
#        life_expectancy  years_since_1990  income_per_person_1000
# ...

# %%
plt.scatter(x='income_per_person_1000',
            y= "life_expectancy",
            data = demo_data_2019)
plt.xlabel("Income per per person (1000$,ppp)")
plt.ylabel("Life expactancy")
plt.title("Scatterplot of income per person vs life expectancy")
# Out:
# Text(0.5, 1.0, 'Scatterplot of income per person vs life expectancy')

# %% [markdown]
# ### Limits
#
# - plt.xlim
# - plt.ylim

# %%
plt.scatter(x='income_per_person_1000',
            y= "life_expectancy",
            data = demo_data_2019)
plt.xlabel("Income per per person (1000$,ppp)")
plt.ylabel("Life expactancy")
plt.title("Scatterplot of income per person vs life expectancy")
plt.xlim(0, 25)
# Out:
# (0.0, 25.0)

# %% [markdown]
# ### Axis ticks
#
# - plt.yticks
# - plt.xticks

# %%
plt.scatter(x='income_per_person_1000',
            y= "life_expectancy",
            data = demo_data_2019)
plt.xlabel("Income per per person (1000$,ppp)")
plt.ylabel("Life expactancy")
plt.title("Scatterplot of income per person vs life expectancy")
plt.yticks([40, 50, 60, 80, 100])
plt.xticks(range(10,110,10));

# the semicolon suppresses all the text spam in the output

# %% [markdown]
# ## lineplot in seaborn

# %%
sns.scatterplot(data = demo_data_2019, x="income_per_person", y="life_expectancy");

# %%
sns.histplot(data = demo_data_2019, x="income_per_person");

# %%
demo_data_japan = demographic_data[demographic_data["country"]== "Japan"]

# %%
sns.lineplot(demo_data_japan, x = "year", y = "fertility_rate");

# %%
demographic_data = demographic_data_copy.copy()
demo_data_2019 = demographic_data[demographic_data["year"] == 2019].copy()

sns.barplot(data=demo_data_2019.head(5), x="country", y="life_expectancy")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 demographic_data = demographic_data_copy.copy()
#       2 demo_data_2019 = demographic_data[demographic_data["year"] == 2019].copy()
#       4 sns.barplot(data=demo_data_2019.head(5), x="country", y="life_expectancy")
#
# AttributeError: 'function' object has no attribute 'copy'

# %%
ordered_data= demo_data_2019.sort_values("life_expectancy").head(5)

# %%
sns.barplot(data=ordered_data,x="country",y="life_expectancy");

# %% [markdown]
# ## Bar plots for summarisation

# %%
last_20 = demographic_data[demographic_data["year"] > 2000]

last_20
# Out:
#            country  year  fertility_rate  income_per_person  life_expectancy
# 101    Afghanistan  2001            7.39              646.0             54.8
# 102    Afghanistan  2002            7.27             1020.0             55.6
# 103    Afghanistan  2003            7.14             1060.0             56.4
# 104    Afghanistan  2004            6.99             1020.0             56.9
# 105    Afghanistan  2005            6.83             1100.0             57.4
# ...            ...   ...             ...                ...              ...
# 22075     Zimbabwe  2015            3.84             2510.0             59.6
# 22076     Zimbabwe  2016            3.76             2490.0             60.5
# 22077     Zimbabwe  2017            3.68             2570.0             61.4
# 22078     Zimbabwe  2018            3.61             2620.0             61.7
# 22079     Zimbabwe  2019            3.53             2390.0             62.0
#
# [3496 rows x 5 columns]

# %%
sns.barplot(data=last_20, x = "income_per_person", y = "year", estimator = np.mean, ci=False, orient="h").invert_yaxis();
plt.xticks(rotation = 45);
# Out:
# C:\Users\Andrew\AppData\Local\Temp\ipykernel_11220\497876457.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(data=last_20, x = "income_per_person", y = "year", estimator = np.mean, ci=False, orient="h").invert_yaxis();

# %% [markdown]
# Read in the occupation_prestige data.
# - Create a plot to show the relationship between prestige and education.
# - Create a plot to show the minimum prestige score for each occupation type (i.e. the type variable).
# - Add a title and new axis labels to your 2nd graph.

# %%
sns.scatterplot(data = prestige_occupation, x = "prestige", y = "education");

# %%
sns.barplot(data = prestige_occupation, x = "type", y = "prestige", estimator = np.min, ci = False);

plt.xlabel("Occupation type")
plt.ylabel("Min Prestige score")
plt.title("Min prestige score for each occupation type")
# Out:
# C:\Users\Andrew\AppData\Local\Temp\ipykernel_11220\1384070525.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(data = prestige_occupation, x = "type", y = "prestige", estimator = np.min, ci = False);
# Text(0.5, 1.0, 'Min prestige score for each occupation type')

# %%
import dtale as dta

# %% [markdown]
# ## Make plots pretty
#
# https://matplotlib.org/3.1.0/gallery/color/named_colors.html

# %%
demo_data_2019
# Out:
#                         country  year  fertility_rate  income_per_person  \
# 17279                 Singapore  2019            1.27            90100.0
# 9839                      Japan  2019            1.50            39700.0
# 19199               Switzerland  2019            1.56            59000.0
# 9599                      Italy  2019            1.51            35800.0
# 9479                     Israel  2019            2.89            34100.0
# ...                         ...   ...             ...                ...
# 18119               South Sudan  2019            4.62             1860.0
# 17759                   Somalia  2019            5.98              631.0
# 15239          Papua New Guinea  2019            3.52             3930.0
# 11039                   Lesotho  2019            2.95             2920.0
# 3839   Central African Republic  2019            4.65              794.0
#
#        life_expectancy  years_since_1990  income_per_person_1000
# ...

# %%
sns.scatterplot(data=demo_data_2019, x = "income_per_person", y="life_expectancy");

# %%
sns.scatterplot(data=demo_data_2019, x = "income_per_person", y="life_expectancy", color = "firebrick");

# %% [markdown]
# ### colour schemes
#
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %% [markdown]
# #### Continuous data

# %%
sns.scatterplot(data=demo_data_2019, x = "income_per_person", y="life_expectancy", hue="fertility_rate", palette = "mako_r");

# %% [markdown]
# #### Categorical (discrete) data

# %%
demo_data_2019["fertility_rate_above_5"] = np.where(demo_data_2019["fertility_rate"] > 5, "yes", "no")

demo_data_2019
# Out:
#                         country  year  fertility_rate  income_per_person  \
# 17279                 Singapore  2019            1.27            90100.0
# 9839                      Japan  2019            1.50            39700.0
# 19199               Switzerland  2019            1.56            59000.0
# 9599                      Italy  2019            1.51            35800.0
# 9479                     Israel  2019            2.89            34100.0
# ...                         ...   ...             ...                ...
# 18119               South Sudan  2019            4.62             1860.0
# 17759                   Somalia  2019            5.98              631.0
# 15239          Papua New Guinea  2019            3.52             3930.0
# 11039                   Lesotho  2019            2.95             2920.0
# 3839   Central African Republic  2019            4.65              794.0
#
#        life_expectancy  years_since_1990  income_per_person_1000  \
# ...

# %%
sns.scatterplot(data= demo_data_2019, x = "income_per_person", y = "life_expectancy", hue = "fertility_rate_above_5");
